# %% [markdown]
# # Import numpy

# %%
import numpy as np

# %% [markdown]
# # Import Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Import cv2

# %%
import cv2

# %% [markdown]
# ### Load an Image

# %%
image = cv2.imread('bmw13.jpg')
'''cv2.imread() takes a single argument which is the path to image'''
# Out:
# 'cv2.imread() takes a single argument which is the path to image'

# %% [markdown]
# ### Display an image

# %%
cv2.imshow('image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
#use escape key to close the windows

# %% [markdown]
# ## Show by Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


image  = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %% [markdown]
# ### Saving  image

# %%
cv2.imwrite('newImage.jpg' , image)
# Out:
# True

# %% [markdown]
# ### Convert BGR to Grayscale and RGB

# %%
gray =cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)
# display it
# cv2.imshow('gray' , gray)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# plot display
plt.imshow(gray)
plt.show()

# %%
rgb = cv2.cvtColor(image , cv2.COLOR_BGR2RGB)
# Display it
cv2.imshow('RGB', rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Displaying all together

# %%
cv2.imshow('original', image)
cv2.imshow('gray', gray)
cv2.imshow('rgb', rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()

#use escape key to close the windows

# %% [markdown]
# ### Getting Height, Width and Depth of Image

# %%
image.shape
# Out:
# (183, 275, 3)

# %%
'''Getting Height'''
h = image.shape[0]

'''Getting Width'''
w = image.shape[1]

'''Getting Depth'''
d = image.shape[2]

print('The Height, Width and Channles of the Image are : {}, {}, {}'.format(h, w, d))
# Out:
# The Height, Width and Channles of the Image are : 183, 275, 3

# %% [markdown]
# # 2. Getting Started with Videos

# %%
import cv2

# %% [markdown]
# ### Capture Video from webcam

# %%
video = cv2.VideoCapture(0)
''' Cv2 has function VideoCapture which Capture video from Camera
    Argument Zero(0) means Capture from Laptop 
    
    Here I am running a True Loop which means Capture till Video is there 
'''
while(True):
	ret,frame = video.read()
	cv2.imshow('result', frame)
	cv2.waitKey(1)
	if cv2.waitKey(33) == 27:
		break
''' Here the above two lines means if 'ESC' key is pressed Stop the video
'''

cv2.destroyAllWindows()

# %%
video.release()
''' Releasing the Camera
'''

# %% [markdown]
# ### Displaying Local Video

# %%
video = cv2.VideoCapture('animal.mp4')
''' Cv2 has function VideoCapture which Capture video from Camera
    Argument Zero(0) means Capture from Laptop 
    
    Here I am running a True Loop which means Capture till Video is there 
'''
while True:
    ret, frame = video.read()
    frame = cv2.resize(frame, (600, 400))
    cv2.imshow('result', frame)
    cv2.waitKey(1)
    if cv2.waitKey(33) == 27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# # 3. Drawing Functions in OpenCV
# we can use OpenCV functions to draw different Shapes like line, rectangle, circle etc

# %% [markdown]
# # Draw Line

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img =np.zeros((400,400,3) , dtype='uint8')
a=img.copy()
cv2.imshow('blank' ,a)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Draw Line

# %%
line = cv2.line(a, (50,50), (350,350), (0, 0, 255), 3)
a=cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
# cv2.imshow('line' ,line)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(a)
plt.show()

# %% [markdown]
# # Cross Lines

# %%
line = cv2.line(a, (50,50), (350,350), (0, 0, 255), 3)
line_ = cv2.line(a, (50,350), (350,50), (0, 0, 255), 3)
a=cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
plt.imshow(a)
plt.show()

# %% [markdown]
# # Drawing Rectangle

# %%
img = np.zeros((400, 400, 3), dtype = 'uint8')

b = img.copy()

rectangle = cv2.rectangle(b,(50, 50), (350, 350), (0, 0, 255), 3)
b=cv2.cvtColor(b, cv2.COLOR_BGR2RGB)
''' first argument is image, Start position, End position, Color and thickness
'''
plt.imshow(b)
plt.show()

# %% [markdown]
# # Drawing Circle

# %%
c = img.copy()
# calculating the  center of img
(x, y) = (int(img.shape[1]/2), int(img.shape[0]/2))


circle = cv2.circle(c, (x,y), (120), (0, 0, 255), 3)
c=cv2.cvtColor(c, cv2.COLOR_BGR2RGB)
''' first argument is image, center position, radius, color and thickness 
'''
plt.imshow(c)
plt.show()

# %% [markdown]
# # Combining Together

# %%
(x, y) = (int(img.shape[1]/2), int(img.shape[0]/2))

d = img.copy()

line_1 = cv2.line(d, (50,50), (350,350), (0, 0, 255), 3)

line_ = cv2.line(d, (50,350), (350,50), (0, 0, 255), 3)

rectangle_1 = cv2.rectangle(d,(50, 50), (350, 350), (0, 0, 255), 3)

circle_ = cv2.circle(d, (x,y), (60), (0, 0, 255), 3)

circle_1 = cv2.circle(d, (x,y), (120), (0, 0, 255), 3)
d=cv2.cvtColor(d, cv2.COLOR_BGR2RGB)

plt.imshow(d)
plt.show()

# %% [markdown]
# #  Mouse as a Paint Brush

# %%
import cv2
import numpy as np

# mouse callback function
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        cv2.circle(img,(x,y),100,(128, 0, 128),-1)

# Create a black image, a window and bind the function to window
img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)

while(1):
    cv2.imshow('image',img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# mouse callback function
def draw_rectangle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        rectangle_1 = cv2.rectangle(img,(50, 50), (350, 350), (128, 0, 128), -1)

# Create a black image, a window and bind the function to window
img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_rectangle)

while(1):
    cv2.imshow('image',img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# ## ASSIGNMENT

# %% [markdown]
# ## Draw Ellipse

# %%
img = np.zeros((400, 400, 3), dtype = 'uint8')
el = img.copy()

center_coordinates = (150, 150) 
  
axesLength = (100, 50) 
  
angle = 0
  
startAngle = 0
  
endAngle = 360
   
# Red color in BGR 
color = (0, 0, 255) 
   
# Line thickness of 5 px 
thickness = 5
   
# Using cv2.ellipse() method 
# Draw a ellipse with red line borders of thickness of 5 px 
el = cv2.ellipse(el, center_coordinates, axesLength, 
           angle, startAngle, endAngle, color, thickness) 

# ellipse = cv2.ellipse(el ,(120,100),(100,50) ,(0) , (0), (360) (0, 0, 255), 5)
#  cv2.ellipse(image, center_coordinates, axesLength,angle, startAngle, endAngle, color, thickness) 
plt.imshow(el)
plt.show()

# %% [markdown]
# # Polygon

# %%
pt=img.copy()
penta = np.array([[[40,160],[120,100],[200,160],[160,240],[80,240]]], np.int32)
# triangle = np.array([[[240, 130], [380, 230], [190, 280]]], duint8)
# cv2.polylines(pt, [triangle], True, (0,255,0), thickness=3)
 
img_mod = cv2.polylines(pt, [penta], True, (255,120,255),3)
 
# cv2.imshow('Shapes', img_mod)
 
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img_mod)
plt.show()
